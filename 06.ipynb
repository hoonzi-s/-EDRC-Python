# %% [markdown]
# <a href="https://colab.research.google.com/github/hoonzi-s/EDRC_Python/blob/main/06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Excel 읽어오기
df = pd.read_excel('/content/drive/MyDrive/EDRC_Python/excel_nonlinear_data_1.xlsx')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       14 non-null     float64
#  1   y       14 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 352.0 bytes

# %%
data = df.values
x_data = df.iloc[:, 0].values
y_data = df.iloc[:, 1].values

# %%
plt.figure()
plt.scatter(x_data, y_data)
plt.show()

# %%
# 3D 그래프 그리기
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter

# %%
x = np.arange(0, 10)
y = 0.4 * x ** 2
z = 4 * x + y

fig1 = plt.figure(1)
ax = fig1.add_subplot(111, projection = '3d')
ax.scatter(x, y, z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.title('3D Graph Example')
plt.show()

# %%
# 교과서 예제 1
u = np.linspace(0, 2 * np.pi, 100)
v = np.linspace(0, np.pi, 100)
x = 10 * np.outer(np.cos(u), np.sin(v))
x = 10 * np.outer(np.sin(u), np.cos(v))
z = 10 * np.outer(np.ones(np.size(u)), np.cos(v))

ax.plot_surface(x, y, z, color = 'b')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.title('3D Mesh Graph')
plt.show()

# %%
u = np.linspace(0, 2 * np.pi, 100)
v = np.linspace(0, np.pi, 100)
x = 10 * np.outer(np.cos(u), np.sin(v))
y = 10 * np.outer(np.sin(u), np.sin(v))
z = 10 * np.outer(np.ones(np.size(u)), np.cos(v))

# Plot the surface
ax.plot_surface(x, y, z, color='b')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.title('3D graph example')
plt.show()

# %%
np.size(z)
# Out:
# 10

# %%
np.size(y)
# Out:
# 10
